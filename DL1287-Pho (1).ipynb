# %%
import os
import warnings
import pandas as pd
import numpy as np
import torch
from transformers import PhobertTokenizer, RobertaForSequenceClassification, Trainer, TrainingArguments
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import accuracy_score, f1_score, classification_report
import logging
import torch.nn as nn

warnings.filterwarnings("ignore")
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
os.environ['CUDA_LAUNCH_BLOCKING'] = '1'
os.environ['WANDB_DISABLED'] = 'true'
logging.getLogger("transformers").setLevel(logging.ERROR)

# %%
# ====== ĐƯỜNG DẪN FILE ======
TRAIN_FILE = r"/content/Depression1287_train.xlsx"
VALID_FILE = r"/content/Depression1287_valid.xlsx"
TEST_FILE  = r"/content/Depression1287_test.xlsx"

# ====== ĐỌC DỮ LIỆU ======
train_df = pd.read_excel(TRAIN_FILE)
valid_df = pd.read_excel(VALID_FILE)
test_df  = pd.read_excel(TEST_FILE)


# ====== LABEL ENCODING (0..3) ======
label_order = ["1-Bình thường", "2-Nhẹ", "3-Vừa", "4-Nặng"]
label2id = {lbl: i for i, lbl in enumerate(label_order)}
id2label = {i: lbl for lbl, i in label2id.items()}

# Ánh xạ nhãn
y_train = train_df["Label"].astype(str).map(label2id)
y_valid = valid_df["Label"].astype(str).map(label2id)
y_test  = test_df["Label"].astype(str).map(label2id)

# Lấy text
Xtrain_text = train_df["Content"].astype(str).tolist()
Xvalid_text = valid_df["Content"].astype(str).tolist()
Xtest_text  = test_df["Content"].astype(str).tolist()

# %%
class_weights = compute_class_weight(
    class_weight='balanced',
    classes=np.unique(y_train),
    y=y_train.values
)
class_weights_dict = {i: class_weights[i] for i in range(len(class_weights))}
print(class_weights_dict)
class_weights_tensor = torch.tensor(class_weights, dtype=torch.float)

class WeightedTrainer(Trainer):
    def __init__(self, class_weights=None, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.class_weights = class_weights

    def compute_loss(self, model, inputs, return_outputs=False, **kwargs):
        labels = inputs.get("labels")
        outputs = model(
            input_ids=inputs["input_ids"],
            attention_mask=inputs["attention_mask"]
        )
        logits = outputs.logits

        loss_fct = nn.CrossEntropyLoss(weight=self.class_weights.to(model.device))
        loss = loss_fct(logits.view(-1, model.config.num_labels),
                        labels.view(-1))

        return (loss, outputs) if return_outputs else loss
# Out:
# {0: np.float64(0.36883223684210525), 1: np.float64(1.180263157894737), 2: np.float64(2.7347560975609757), 3: np.float64(13.191176470588236)}

# %%
# ====== TOKENIZER ======
MODEL_NAME = "vinai/phobert-base"
tokenizer = PhobertTokenizer.from_pretrained(MODEL_NAME)

# Tokenize dữ liệu
def tokenize_function(texts):
    return tokenizer(texts, padding=True, truncation=True, max_length=256)

print("🔄 Đang tokenize dữ liệu...")
train_encodings = tokenize_function(Xtrain_text)
valid_encodings = tokenize_function(Xvalid_text)
test_encodings = tokenize_function(Xtest_text)
# Out:
# vocab.txt: 0.00B [00:00, ?B/s]
# bpe.codes: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# config.json:   0%|          | 0.00/557 [00:00<?, ?B/s]
# 🔄 Đang tokenize dữ liệu...

# %%
# Cell 5: Tạo PyTorch Dataset
class DepressionDataset(torch.utils.data.Dataset):
    def __init__(self, encodings, labels):
        self.encodings = encodings
        self.labels = labels

    def __len__(self):
        return len(self.labels)

    def __getitem__(self, idx):
        item = {
            'input_ids': torch.tensor(self.encodings['input_ids'][idx]),
            'attention_mask': torch.tensor(self.encodings['attention_mask'][idx])
        }
        item["labels"] = torch.tensor(self.labels.iloc[idx], dtype=torch.long)
        return item

train_dataset = DepressionDataset(train_encodings, y_train)
valid_dataset = DepressionDataset(valid_encodings, y_valid)
test_dataset = DepressionDataset(test_encodings, y_test)

# %%
# Cell 6: Khởi tạo mô hình
model = RobertaForSequenceClassification.from_pretrained(
    MODEL_NAME,
    num_labels=4,
    id2label=id2label,
    label2id=label2id
)
# Out:
# pytorch_model.bin:   0%|          | 0.00/543M [00:00<?, ?B/s]

# %%
def compute_metrics(p):
    predictions, labels = p
    predictions = np.argmax(predictions, axis=1)

    acc = accuracy_score(labels, predictions)
    f1 = f1_score(labels, predictions, average='weighted')
    return {'accuracy': acc, 'f1': f1}

training_args = TrainingArguments(
    output_dir='./results',
    num_train_epochs=25,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=64,
    eval_strategy="epoch",
    save_strategy="epoch",
    logging_dir='./logs',
    logging_steps=15,
    learning_rate = 3e-5,
    load_best_model_at_end=True,
    metric_for_best_model="f1",
    report_to="none"
)

# %%
trainer = WeightedTrainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=valid_dataset,
    tokenizer=tokenizer,
    compute_metrics=compute_metrics,
    class_weights=class_weights_tensor,
)
train_history = trainer.train()
# Out:
# model.safetensors:   0%|          | 0.00/543M [00:00<?, ?B/s]
# {'loss': 1.4883, 'grad_norm': 5.4980244636535645, 'learning_rate': 2.9705263157894738e-05, 'epoch': 0.2631578947368421}
# {'loss': 1.3887, 'grad_norm': 4.891634941101074, 'learning_rate': 2.9389473684210528e-05, 'epoch': 0.5263157894736842}
# {'loss': 1.3202, 'grad_norm': 2.083486795425415, 'learning_rate': 2.9073684210526314e-05, 'epoch': 0.7894736842105263}
# {'eval_loss': 1.684542179107666, 'eval_accuracy': 0.36153846153846153, 'eval_f1': 0.336804542774692, 'eval_runtime': 1.695, 'eval_samples_per_second': 76.696, 'eval_steps_per_second': 1.77, 'epoch': 1.0}
# {'loss': 1.3495, 'grad_norm': 6.504144191741943, 'learning_rate': 2.8757894736842107e-05, 'epoch': 1.0526315789473684}
# {'loss': 1.4556, 'grad_norm': 3.075618028640747, 'learning_rate': 2.8442105263157897e-05, 'epoch': 1.3157894736842106}
# {'loss': 1.3664, 'grad_norm': 3.5294387340545654, 'learning_rate': 2.8126315789473684e-05, 'epoch': 1.5789473684210527}
# {'loss': 1.3196, 'grad_norm': 3.8392770290374756, 'learning_rate': 2.7810526315789473e-05, 'epoch': 1.8421052631578947}
# {'eval_loss': 1.576332926750183, 'eval_accuracy': 0.5923076923076923, 'eval_f1': 0.5747829121876309, 'eval_runtime': 1.79, 'eval_samples_per_second': 72.624, 'eval_steps_per_second': 1.676, 'epoch': 2.0}
# {'loss': 1.3201, 'grad_norm': 5.9006452560424805, 'learning_rate': 2.7494736842105263e-05, 'epoch': 2.1052631578947367}
# {'loss': 1.2913, 'grad_norm': 6.127729892730713, 'learning_rate': 2.7178947368421053e-05, 'epoch': 2.3684210526315788}
# {'loss': 1.0947, 'grad_norm': 15.713780403137207, 'learning_rate': 2.6863157894736843e-05, 'epoch': 2.6315789473684212}
# {'loss': 1.2223, 'grad_norm': 15.847801208496094, 'learning_rate': 2.6547368421052633e-05, 'epoch': 2.8947368421052633}
# {'eval_loss': 1.2758152484893799, 'eval_accuracy': 0.6307692307692307, 'eval_f1': 0.6033871052546773, 'eval_runtime': 2.0223, 'eval_samples_per_second': 64.283, 'eval_steps_per_second': 1.483, 'epoch': 3.0}
# {'loss': 1.2327, 'grad_norm': 9.769062042236328, 'learning_rate': 2.6231578947368423e-05, 'epoch': 3.1578947368421053}
# {'loss': 1.1264, 'grad_norm': 7.191275596618652, 'learning_rate': 2.591578947368421e-05, 'epoch': 3.4210526315789473}
# {'loss': 1.0987, 'grad_norm': 8.07359504699707, 'learning_rate': 2.5600000000000002e-05, 'epoch': 3.6842105263157894}
# {'loss': 1.0665, 'grad_norm': 17.457033157348633, 'learning_rate': 2.5284210526315792e-05, 'epoch': 3.9473684210526314}
# {'eval_loss': 1.341367483139038, 'eval_accuracy': 0.4153846153846154, 'eval_f1': 0.45125594405594405, 'eval_runtime': 1.9922, 'eval_samples_per_second': 65.254, 'eval_steps_per_second': 1.506, 'epoch': 4.0}
# {'loss': 0.9136, 'grad_norm': 5.33217191696167, 'learning_rate': 2.496842105263158e-05, 'epoch': 4.2105263157894735}
# {'loss': 0.7969, 'grad_norm': 4.8599724769592285, 'learning_rate': 2.465263157894737e-05, 'epoch': 4.473684210526316}
# {'loss': 1.0588, 'grad_norm': 32.58510208129883, 'learning_rate': 2.4336842105263158e-05, 'epoch': 4.7368421052631575}
# {'loss': 0.9625, 'grad_norm': 46.19796371459961, 'learning_rate': 2.4021052631578948e-05, 'epoch': 5.0}
# {'eval_loss': 1.4567844867706299, 'eval_accuracy': 0.3769230769230769, 'eval_f1': 0.38900183150183143, 'eval_runtime': 2.0376, 'eval_samples_per_second': 63.8, 'eval_steps_per_second': 1.472, 'epoch': 5.0}
# {'loss': 0.7794, 'grad_norm': 8.372568130493164, 'learning_rate': 2.3705263157894738e-05, 'epoch': 5.2631578947368425}
# {'loss': 0.7504, 'grad_norm': 22.64161491394043, 'learning_rate': 2.3389473684210528e-05, 'epoch': 5.526315789473684}
# {'loss': 0.7018, 'grad_norm': 52.226314544677734, 'learning_rate': 2.3073684210526317e-05, 'epoch': 5.7894736842105265}
# {'eval_loss': 1.749310851097107, 'eval_accuracy': 0.6, 'eval_f1': 0.6170664118490206, 'eval_runtime': 2.0123, 'eval_samples_per_second': 64.604, 'eval_steps_per_second': 1.491, 'epoch': 6.0}
# {'loss': 0.6398, 'grad_norm': 7.660251140594482, 'learning_rate': 2.2757894736842104e-05, 'epoch': 6.052631578947368}
# {'loss': 0.4767, 'grad_norm': 9.962977409362793, 'learning_rate': 2.2442105263157894e-05, 'epoch': 6.315789473684211}
# {'loss': 0.0166, 'grad_norm': 0.032554153352975845, 'learning_rate': 7.600000000000001e-06, 'epoch': 18.68421052631579}
# {'loss': 0.0039, 'grad_norm': 0.04455304518342018, 'learning_rate': 7.284210526315789e-06, 'epoch': 18.94736842105263}
# {'eval_loss': 4.025974273681641, 'eval_accuracy': 0.5846153846153846, 'eval_f1': 0.6081425026586317, 'eval_runtime': 2.0546, 'eval_samples_per_second': 63.272, 'eval_steps_per_second': 1.46, 'epoch': 19.0}
# {'loss': 0.0116, 'grad_norm': 0.05940789729356766, 'learning_rate': 6.96842105263158e-06, 'epoch': 19.210526315789473}
# {'loss': 0.004, 'grad_norm': 0.09162481129169464, 'learning_rate': 6.652631578947369e-06, 'epoch': 19.473684210526315}
# {'loss': 0.0035, 'grad_norm': 0.03412635996937752, 'learning_rate': 6.3368421052631585e-06, 'epoch': 19.736842105263158}
# {'loss': 0.0037, 'grad_norm': 0.04422325640916824, 'learning_rate': 6.0210526315789475e-06, 'epoch': 20.0}
# {'eval_loss': 4.109100341796875, 'eval_accuracy': 0.6153846153846154, 'eval_f1': 0.633393589313804, 'eval_runtime': 2.0357, 'eval_samples_per_second': 63.862, 'eval_steps_per_second': 1.474, 'epoch': 20.0}
# {'loss': 0.0095, 'grad_norm': 0.05661672353744507, 'learning_rate': 5.7052631578947365e-06, 'epoch': 20.263157894736842}
# {'loss': 0.0087, 'grad_norm': 0.038899119943380356, 'learning_rate': 5.389473684210526e-06, 'epoch': 20.526315789473685}
# {'loss': 0.0034, 'grad_norm': 0.03485206514596939, 'learning_rate': 5.073684210526316e-06, 'epoch': 20.789473684210527}
# {'eval_loss': 4.141592979431152, 'eval_accuracy': 0.6153846153846154, 'eval_f1': 0.6346745562130177, 'eval_runtime': 2.0224, 'eval_samples_per_second': 64.279, 'eval_steps_per_second': 1.483, 'epoch': 21.0}
# {'loss': 0.0032, 'grad_norm': 0.031173352152109146, 'learning_rate': 4.757894736842106e-06, 'epoch': 21.05263157894737}
# {'loss': 0.0086, 'grad_norm': 0.05458527058362961, 'learning_rate': 4.442105263157895e-06, 'epoch': 21.31578947368421}
# {'loss': 0.0035, 'grad_norm': 0.04462629556655884, 'learning_rate': 4.126315789473684e-06, 'epoch': 21.57894736842105}
# {'loss': 0.0034, 'grad_norm': 0.04142119735479355, 'learning_rate': 3.8105263157894733e-06, 'epoch': 21.842105263157894}
# {'eval_loss': 4.18620491027832, 'eval_accuracy': 0.6153846153846154, 'eval_f1': 0.6346745562130177, 'eval_runtime': 2.0376, 'eval_samples_per_second': 63.802, 'eval_steps_per_second': 1.472, 'epoch': 22.0}
# {'loss': 0.0075, 'grad_norm': 3.0343949794769287, 'learning_rate': 3.494736842105263e-06, 'epoch': 22.105263157894736}
# {'loss': 0.003, 'grad_norm': 0.028315354138612747, 'learning_rate': 3.1789473684210525e-06, 'epoch': 22.36842105263158}
# {'loss': 0.0042, 'grad_norm': 0.07320956140756607, 'learning_rate': 2.8631578947368423e-06, 'epoch': 22.63157894736842}
# {'loss': 0.0033, 'grad_norm': 0.07014121115207672, 'learning_rate': 2.5473684210526317e-06, 'epoch': 22.894736842105264}
# {'eval_loss': 4.19790506362915, 'eval_accuracy': 0.6076923076923076, 'eval_f1': 0.6281751064546763, 'eval_runtime': 2.0217, 'eval_samples_per_second': 64.303, 'eval_steps_per_second': 1.484, 'epoch': 23.0}
# {'loss': 0.0028, 'grad_norm': 0.0381755493581295, 'learning_rate': 2.231578947368421e-06, 'epoch': 23.157894736842106}
# {'loss': 0.0029, 'grad_norm': 0.026744453236460686, 'learning_rate': 1.9157894736842105e-06, 'epoch': 23.42105263157895}
# {'loss': 0.0093, 'grad_norm': 0.05295838415622711, 'learning_rate': 1.6000000000000001e-06, 'epoch': 23.68421052631579}
# {'loss': 0.0031, 'grad_norm': 0.0672726109623909, 'learning_rate': 1.2842105263157895e-06, 'epoch': 23.94736842105263}
# {'eval_loss': 4.208566188812256, 'eval_accuracy': 0.6076923076923076, 'eval_f1': 0.6281751064546763, 'eval_runtime': 2.0125, 'eval_samples_per_second': 64.597, 'eval_steps_per_second': 1.491, 'epoch': 24.0}
# {'loss': 0.0028, 'grad_norm': 0.022930635139346123, 'learning_rate': 9.68421052631579e-07, 'epoch': 24.210526315789473}
# {'loss': 0.0137, 'grad_norm': 0.027431152760982513, 'learning_rate': 6.526315789473684e-07, 'epoch': 24.473684210526315}
# {'loss': 0.003, 'grad_norm': 0.031159089878201485, 'learning_rate': 3.368421052631579e-07, 'epoch': 24.736842105263158}
# {'loss': 0.0027, 'grad_norm': 0.04887241870164871, 'learning_rate': 2.1052631578947368e-08, 'epoch': 25.0}
# {'eval_loss': 4.218367099761963, 'eval_accuracy': 0.6076923076923076, 'eval_f1': 0.6281751064546763, 'eval_runtime': 2.0231, 'eval_samples_per_second': 64.258, 'eval_steps_per_second': 1.483, 'epoch': 25.0}
# {'train_runtime': 1908.5767, 'train_samples_per_second': 11.75, 'train_steps_per_second': 0.747, 'train_loss': 0.34760412228996296, 'epoch': 25.0}

# %%
test_results = trainer.evaluate(test_dataset)
predictions = trainer.predict(test_dataset)
predicted_labels = np.argmax(predictions.predictions, axis=1)
true_labels = y_test.values
print(classification_report(true_labels, predicted_labels,
                          target_names=[id2label[i] for i in range(4)]))
# Out:
# {'eval_loss': 1.9451850652694702, 'eval_accuracy': 0.6692307692307692, 'eval_f1': 0.6513640238704177, 'eval_runtime': 3.7153, 'eval_samples_per_second': 69.981, 'eval_steps_per_second': 1.346, 'epoch': 25.0}
#                precision    recall  f1-score   support
#
# 1-Bình thường       0.76      0.85      0.80       174
#         2-Nhẹ       0.42      0.27      0.33        56
#         3-Vừa       0.33      0.38      0.35        24
#        4-Nặng       0.67      0.33      0.44         6
#
#      accuracy                           0.67       260
#     macro avg       0.54      0.46      0.48       260
#  weighted avg       0.65      0.67      0.65       260
